# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import hyperopt
import euclidemu2 as ee2
import keras
import train_utils as utils
from train_utils import params, lims, ref
# Out:
# 2023-05-17 15:54:30.386824: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-17 15:54:30.414777: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
redshifts = [0, 0.5, 1.0, 2.0, 3.0]

# %% [markdown]
# ## $\Lambda$CDM - 400 training points

# %% [markdown]
# ### Data preprocessing

# %%
# This folder is also in OwnCloud
path_to_spectra = "/home/grads/data/jonathan/halofit_tests_takahashi/lcdm"
path_to_train400_0percent = path_to_spectra + "/0_percent/400"
path_to_train400_10percent = path_to_spectra + "/10_percent/400"
path_to_train400_20percent = path_to_spectra + "/20_percent/400"

# %%
# Set which LHS stretch to use
path_to_train = path_to_train400_10percent

# %%
# Calculate ref cosmology from CAMB, all redshifts
pk_lin_ref = np.zeros((len(redshifts), len(utils.ks_400)))
pk_nl_ref = np.zeros((len(redshifts), len(utils.ks_400)))
pk_lin_smear_ref = np.zeros((len(redshifts), len(utils.ks_400)))
for i, redshift in enumerate(redshifts):
    ks, pk_lin_ref[i], pk_nl_ref[i] = np.loadtxt(f"{path_to_train}/pk_ref_z_{redshift:.3f}.txt", unpack=True)
    pk_lin_smear_ref[i] = utils._smeared_bao_pk(k_lin=ks, pk_lin=pk_lin_ref[i], k_emu=ks, pk_lin_emu=pk_lin_ref[i])
ref_boost = pk_nl_ref/pk_lin_ref
ref_expq = pk_nl_ref/pk_lin_smear_ref

# %%
# Read training LHS
train_samples_400 = np.loadtxt(f"{path_to_train}/lhs.txt")
print(train_samples_400[0])
# Out:
# [2.98998249e-01 5.84627549e-02 9.66097472e-01 1.99213595e-09
#  6.75717014e-01]

# %%
# Read training data, 400 spectra
pks_lin_train400 = np.zeros((len(train_samples_400), len(redshifts), len(utils.ks_400)))
pks_lin_smear_train400 = np.zeros((len(train_samples_400), len(redshifts), len(utils.ks_400)))
pks_nl_train400 = np.zeros((len(train_samples_400), len(redshifts), len(utils.ks_400)))

for i in range(len(train_samples_400)):
    for j, redshift in enumerate(redshifts):
        ks, pks_lin_train400[i,j], pks_nl_train400[i,j] = np.loadtxt(f"{path_to_train}/pk_{i}_z_{redshift:.3f}.txt", unpack=True)
        pks_lin_smear_train400[i,j] = utils._smeared_bao_pk(k_lin=ks, pk_lin=pks_lin_train400[i,j], k_emu=ks, pk_lin_emu=pks_lin_train400[i,j])

# %%
# Defining emulated quantities
train_logboosts = np.zeros((len(train_samples_400), len(redshifts), len(utils.ks_400)))
train_qs = np.zeros((len(train_samples_400), len(redshifts), len(utils.ks_400)))
for i in range(len(train_samples_400)):
    r_nl = pks_nl_train400[i]/pk_nl_ref
    r_lin = pks_lin_train400[i]/pk_lin_ref
    r_lin_smear = pks_lin_smear_train400[i]/pk_lin_smear_ref
    train_logboosts[i] = np.log(ref_boost * r_nl / r_lin)
    train_qs[i] = np.log(ref_expq * r_nl / r_lin_smear)

# %%
# Normalized parameters - input for NN
train_sample_norm = np.zeros((len(train_samples_400),5))
for i, train_point in enumerate(train_samples_400):
    train_sample_norm[i] = utils.normalize_params(train_point)

# %%
# Normalized Boosts with Min-Max
train_logboosts_norm = np.zeros((len(train_samples_400), len(redshifts), len(ks)))
train_qs_norm = np.zeros((len(train_samples_400), len(redshifts), len(ks)))
for i in range(len(redshifts)):
    train_logboosts_norm[:,i,:] = utils.normalize_array(train_logboosts[:,i,:]) # I normalize within each redshift
    train_qs_norm[:,i,:] = utils.normalize_array(train_qs[:,i,:]) # I normalize within each redshift

# %%
# Getting and saving min and max for rescaling
mins_logboosts = np.zeros(len(redshifts))
maxs_logboosts = np.zeros(len(redshifts))
mins_qs = np.zeros(len(redshifts))
maxs_qs = np.zeros(len(redshifts))

for i in range(len(redshifts)):
    mins_logboosts[i] = np.amin(train_logboosts[:,i,:])
    maxs_logboosts[i] = np.amax(train_logboosts[:,i,:])
    mins_qs[i] = np.amin(train_qs[:,i,:])
    maxs_qs[i] = np.amax(train_qs[:,i,:])

# %%
# PCA reduction
num_pcs = 6
pcas_logboosts, train_logboosts_pcs = utils.pca_reduction(num_pcs, train_logboosts_norm, redshifts)
pcas_qs, train_qs_pcs = utils.pca_reduction(num_pcs, train_qs_norm, redshifts)

# %%
# Normalizing PCs
train_logboosts_pcs_norm = np.zeros((len(train_samples_400), len(redshifts), num_pcs))
train_qs_pcs_norm = np.zeros((len(train_samples_400), len(redshifts), num_pcs))
for i in range(len(redshifts)):
    train_logboosts_pcs_norm[:,i] = utils.normalize_array(train_logboosts_pcs[:,i]) # I normalize within each redshift
    train_qs_pcs_norm[:,i] = utils.normalize_array(train_qs_pcs[:,i]) # I normalize within each redshift

# Saving mins and maxs for rescaling
mins_logboosts_pcs = np.zeros((len(redshifts)))
maxs_logboosts_pcs = np.zeros((len(redshifts)))
mins_qs_pcs = np.zeros((len(redshifts)))
maxs_qs_pcs = np.zeros((len(redshifts)))
for i in range(len(redshifts)):
        mins_logboosts_pcs[i] = np.amin(train_logboosts_pcs[:,i])
        maxs_logboosts_pcs[i] = np.amax(train_logboosts_pcs[:,i])
        mins_qs_pcs[i] = np.amin(train_qs_pcs[:,i])
        maxs_qs_pcs[i] = np.amax(train_qs_pcs[:,i])

# %% [markdown]
# ### Training

# %%
# Generate resnet model
resnet = utils.generate_resnet(num_pcs, 1, train_sample_norm, num_of_neurons=1024, alpha=1e-4, l1_ratio=0.1, dropout=0)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5)]          0           []
#
#  dense_3 (Dense)                (None, 1024)         6144        ['input_2[0][0]']
#
#  dense_4 (Dense)                (None, 1024)         1049600     ['dense_3[0][0]']
#
#  add_1 (Add)                    (None, 1024)         0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 6)            6150        ['add_1[0][0]']
#
# ==================================================================================================
# Total params: 1,061,894
# Trainable params: 1,061,894
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Generate MLP model
mlp = utils.generate_model_regularized(num_pcs, 2, train_sample_norm, num_of_neurons=1024, alpha=1e-4, l1_ratio=0.1, dropout=0)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hid_layer_1 (Dense)         (None, 1024)              6144
#
#  hid_layer_2 (Dense)         (None, 1024)              1049600
#
#  out_layer (Dense)           (None, 6)                 6150
#
# =================================================================
# Total params: 1,061,894
# Trainable params: 1,061,894
# Non-trainable params: 0
# _________________________________________________________________

# %%
from time import perf_counter
start = perf_counter()
last_loss = utils.nn_model_train(resnet, 1600, train_sample_norm, train_qs_pcs_norm[:,0], decayevery=1550, decayrate=2)
last_loss = utils.nn_model_train(resnet, 1000, train_sample_norm, train_qs_pcs_norm[:,0], decayevery=200, decayrate=2)
print(f"Training took {perf_counter() - start} seconds")
# Out:
# Epoch 1/2000
# 14/14 [==============================] - 1s 7ms/step - loss: 0.5439 - lr: 0.0010
# Epoch 2/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3893 - lr: 0.0010
# Epoch 3/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3144 - lr: 0.0010
# Epoch 4/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2554 - lr: 0.0010
# Epoch 5/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1637 - lr: 0.0010
# Epoch 6/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1326 - lr: 0.0010
# Epoch 7/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1099 - lr: 0.0010
# Epoch 8/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0973 - lr: 0.0010
# Epoch 9/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0876 - lr: 0.0010
# Epoch 10/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0787 - lr: 0.0010
# Epoch 11/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0710 - lr: 0.0010
# Epoch 12/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0662 - lr: 0.0010
# Epoch 13/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0604 - lr: 0.0010
# Epoch 14/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0574 - lr: 0.0010
# Epoch 15/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0539 - lr: 0.0010
# Epoch 16/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0518 - lr: 0.0010
# Epoch 17/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0495 - lr: 0.0010
# Epoch 18/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0448 - lr: 0.0010
# Epoch 19/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0430 - lr: 0.0010
# Epoch 20/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0415 - lr: 0.0010
# Epoch 21/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0374 - lr: 0.0010
# Epoch 22/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0374 - lr: 0.0010
# Epoch 23/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0364 - lr: 0.0010
# Epoch 24/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0355 - lr: 0.0010
# Epoch 25/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0346 - lr: 0.0010
# Epoch 26/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0348 - lr: 0.0010
# Epoch 27/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0315 - lr: 0.0010
# Epoch 28/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0287 - lr: 0.0010
# Epoch 29/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0304 - lr: 0.0010
# Epoch 30/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0279 - lr: 0.0010
# Epoch 31/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0286 - lr: 0.0010
# Epoch 32/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0260 - lr: 0.0010
# Epoch 33/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0267 - lr: 0.0010
# Epoch 34/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0296 - lr: 0.0010
# Epoch 35/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0283 - lr: 0.0010
# Epoch 36/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0259 - lr: 0.0010
# Epoch 37/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0226 - lr: 0.0010
# Epoch 38/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0241 - lr: 0.0010
# Epoch 39/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0222 - lr: 0.0010
# Epoch 40/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0228 - lr: 0.0010
# Epoch 41/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0208 - lr: 0.0010
# Epoch 42/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0213 - lr: 0.0010
# Epoch 43/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0207 - lr: 0.0010
# Epoch 44/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0196 - lr: 0.0010
# Epoch 45/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0206 - lr: 0.0010
# Epoch 46/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0199 - lr: 0.0010
# Epoch 47/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0190 - lr: 0.0010
# Epoch 48/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0181 - lr: 0.0010
# Epoch 49/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0199 - lr: 0.0010
# Epoch 50/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0220 - lr: 0.0010
# Epoch 51/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0169 - lr: 0.0010
# Epoch 52/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.
2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0060 - lr: 0.0010
# Epoch 394/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - lr: 0.0010
# Epoch 395/2000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0051 - lr: 0.0010
# Epoch 396/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - lr: 0.0010
# Epoch 397/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0056 - lr: 0.0010
# Epoch 398/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0052 - lr: 0.0010
# Epoch 399/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0069 - lr: 0.0010
# Epoch 400/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0057 - lr: 0.0010
# Epoch 401/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0057 - lr: 0.0010
# Epoch 402/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0049 - lr: 0.0010
# Epoch 403/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0045 - lr: 0.0010
# Epoch 404/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 405/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0048 - lr: 0.0010
# Epoch 406/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0055 - lr: 0.0010
# Epoch 407/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0059 - lr: 0.0010
# Epoch 408/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0061 - lr: 0.0010
# Epoch 409/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0049 - lr: 0.0010
# Epoch 410/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0051 - lr: 0.0010
# Epoch 411/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0053 - lr: 0.0010
# Epoch 412/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0045 - lr: 0.0010
# Epoch 413/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0062 - lr: 0.0010
# Epoch 414/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0058 - lr: 0.0010
# Epoch 415/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0061 - lr: 0.0010
# Epoch 416/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0056 - lr: 0.0010
# Epoch 417/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0050 - lr: 0.0010
# Epoch 418/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0053 - lr: 0.0010
# Epoch 419/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0057 - lr: 0.0010
# Epoch 420/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0064 - lr: 0.0010
# Epoch 421/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0069 - lr: 0.0010
# Epoch 422/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0069 - lr: 0.0010
# Epoch 423/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0048 - lr: 0.0010
# Epoch 424/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0050 - lr: 0.0010
# Epoch 425/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0052 - lr: 0.0010
# Epoch 426/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0059 - lr: 0.0010
# Epoch 427/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0052 - lr: 0.0010
# Epoch 428/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0067 - lr: 0.0010
# Epoch 429/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0066 - lr: 0.0010
# Epoch 430/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0067 - lr: 0.0010
# Epoch 431/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0052 - lr: 0.0010
# Epoch 432/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0063 - lr: 0.0010
# Epoch 433/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0049 - lr: 0.0010
# Epoch 434/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0058 - lr: 0.0010
# Epoch 435/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0050 - lr: 0.0010
# Epoch 436/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0055 - lr: 0.0010
# Epoch 437/2000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0058 - lr: 0.0010
# Epoch 438/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0051 - lr: 0.0010
# Epoch 439/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0052 - lr: 0.0010
# Epoch 440/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0046 - lr: 0.0010
# Epoch 441/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0044 - lr: 0.0010
# Epoch 442/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0045 - lr: 0.0010
# Epoch 443/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0048 - lr: 0.0010
# Epoch 444/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - lr: 0.0010
# Epoch 445/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0062 - lr: 0.0010
# Epoch 446/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0051 - lr: 0.0010
# Epoch 447/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0059 - lr: 0.0010
# Epoch 448/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0062 - lr: 0.0010
# Epoch 449/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0066 - lr: 0.0010
# Epoch 450/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0059 - lr: 0.0010
# Epoch 451/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0062 - lr: 0.0010
# Epoch 452/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0060 - lr: 0.0010
# Epoch 453/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0056 - lr: 0.0010
# Epoch 454/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0058 - lr: 0.0010
# Epoch 455/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - lr: 0.0010
# Epoch 456/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0051 - lr: 0.0010
# Epoch 457/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0051 - lr: 0.0010
# Epoch 458/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0049 - lr: 0.0010
# Epoch 459/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - lr: 0.0010
# Epoch 460/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0054 - lr: 0.0010
# Epoch 461/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0049 - lr: 0.0010
# Epoch 462/2000
# 14/14 [==============================] - 0s 5ms/step - loss: 0.
1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0283e-04 - lr: 3.1250e-05
# Epoch 977/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0345e-04 - lr: 3.1250e-05
# Epoch 978/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0096e-04 - lr: 3.1250e-05
# Epoch 979/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8913e-04 - lr: 3.1250e-05
# Epoch 980/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8936e-04 - lr: 3.1250e-05
# Epoch 981/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8434e-04 - lr: 3.1250e-05
# Epoch 982/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8361e-04 - lr: 3.1250e-05
# Epoch 983/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0074e-04 - lr: 3.1250e-05
# Epoch 984/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9788e-04 - lr: 3.1250e-05
# Epoch 985/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.3473e-04 - lr: 3.1250e-05
# Epoch 986/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.2712e-04 - lr: 3.1250e-05
# Epoch 987/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9981e-04 - lr: 3.1250e-05
# Epoch 988/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0769e-04 - lr: 3.1250e-05
# Epoch 989/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.1734e-04 - lr: 3.1250e-05
# Epoch 990/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9555e-04 - lr: 3.1250e-05
# Epoch 991/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0718e-04 - lr: 3.1250e-05
# Epoch 992/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.1193e-04 - lr: 3.1250e-05
# Epoch 993/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.1904e-04 - lr: 3.1250e-05
# Epoch 994/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9487e-04 - lr: 3.1250e-05
# Epoch 995/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9095e-04 - lr: 3.1250e-05
# Epoch 996/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9615e-04 - lr: 3.1250e-05
# Epoch 997/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.8777e-04 - lr: 3.1250e-05
# Epoch 998/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.0689e-04 - lr: 3.1250e-05
# Epoch 999/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 6.9275e-04 - lr: 3.1250e-05
# Epoch 1000/1000
# 14/14 [==============================] - 0s 5ms/step - loss: 7.1068e-04 - lr: 3.1250e-05
# Training took 217.5474660154432 seconds

# %%
resnet.save("models/resnet_smear_stretch10")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/resnet_smear_stretch10/assets
# INFO:tensorflow:Assets written to: models/resnet_smear_stretch10/assets

# %% [markdown]
# ### Evaluating model

# %%
path_to_spectra = "/home/grads/data/jonathan/halofit_tests_takahashi/lcdm"
path_to_test_spectra = f"{path_to_spectra}/0_percent/300"
test_samples = np.loadtxt(f"{path_to_test_spectra}/lhs.txt")
print(test_samples[0])
ks = np.loadtxt(f"{path_to_test_spectra}/pk_ref_z_0.000.txt", unpack=True, usecols=(0))
# Out:
# [3.96686122e-01 4.49730022e-02 9.87595752e-01 1.90699488e-09
#  6.18228503e-01]

# %%
pks_lin_test = np.zeros((len(test_samples), len(redshifts), len(ks)))
pks_lin_smear_test = np.zeros((len(test_samples), len(redshifts), len(ks)))
pks_nl_test = np.zeros((len(test_samples), len(redshifts), len(ks)))

for i in range(len(test_samples)):
    for j, redshift in enumerate(redshifts):
        ks, pks_lin_test[i,j], pks_nl_test[i,j] = np.loadtxt(f"{path_to_test_spectra}/pk_{i}_z_{redshift:.3f}.txt", unpack=True)
        pks_lin_smear_test[i,j] = utils._smeared_bao_pk(k_lin=ks, pk_lin=pks_lin_test[i,j], k_emu=ks, pk_lin_emu=pks_lin_test[i,j])

# %%
test_boosts = pks_nl_test/pks_lin_test
test_expqs = pks_nl_test/pks_lin_smear_test

# %%
def evaluate_model(model, test_lhs, test_data, z_index, smear):
    """
    Generates a plot of relative errors
    """
    bad_cosmologies = 0
    fig = plt.figure()
    for i, (test_sample, test_boost) in enumerate(zip(test_lhs, test_data)):
        test_params_norm = utils.normalize_params(test_sample)
        nn_test_output = model(np.array([test_params_norm])) # Normalized PCs
        if not smear:
            output_pcs = nn_test_output * (maxs_logboosts_pcs[z_index] - mins_logboosts_pcs[z_index]) + mins_logboosts_pcs[z_index] # PCs
            output_norm_logboost = pcas_logboosts[z_index].inverse_transform(output_pcs) # Norm logboost
            output_logboost = output_norm_logboost * (maxs_logboosts[z_index] - mins_logboosts[z_index]) + mins_logboosts[z_index] # Logboost
        else:
            output_pcs = nn_test_output * (maxs_qs_pcs[z_index] - mins_qs_pcs[z_index]) + mins_qs_pcs[z_index] # PCs
            output_norm_q = pcas_qs[z_index].inverse_transform(output_pcs) # Norm logboost
            output_logboost = output_norm_q * (maxs_qs[z_index] - mins_qs[z_index]) + mins_qs[z_index] # Logboost
        output_boost = np.exp(output_logboost)[0] # Boost
        errors = output_boost/test_boost[z_index] - 1
        #plt.semilogx(ks, output_logboost[0])
        #plt.semilogx(ks, np.log(test_boost[z_index]))
        plt.semilogx(ks, errors)
        if np.any(errors > 0.005):
            bad_cosmologies += 1
    plt.xlabel('$k \;\; (h/\mathrm{Mpc})$')
    plt.ylabel('$B_{emu} / B_{Halofit} - 1$')
    plt.ylim([-0.02, 0.02])
    plt.xlim([0.01, 3])
    print(f"Number of cosmologies with error > 0.005: {bad_cosmologies} out of {len(test_lhs)}")
    plt.grid()
    return fig # in case you want to save, just use fig.savefig("name.pdf"); add title with figure.suptitle("Title")

# %% [markdown]
# ### Evaluation Results

# %%
resnet_smeared_stretch10 = keras.models.load_model("models/resnet_smear_stretch10")
figure = evaluate_model(resnet_smeared_stretch10, test_samples, test_expqs, 0, smear=True)
# Out:
# Number of cosmologies with error > 0.005: 2 out of 300

# %%
figure.suptitle("ResNet errors - 400 train, extended LHS 10%, BACCO smearing")
figure.savefig("resnet_smeared_errors_stretchLHS10.pdf", bbox_inches="tight")

# %%
resnet_smeared_stretch20 = keras.models.load_model("models/resnet_smear_stretch20")
figure = evaluate_model(resnet_smeared_stretch20, test_samples, test_expqs, 0, smear=True)
# Out:
# Number of cosmologies with error > 0.005: 1 out of 300

# %%
figure.suptitle("ResNet errors - 400 train, extended LHS 20%, BACCO smearing")
figure.savefig("resnet_smeared_errors_stretchLHS20.pdf", bbox_inches="tight")

# %%
resnet_smeared = keras.models.load_model("models/resnet_smear")
figure = evaluate_model(resnet_smeared, test_samples, test_expqs, 0, smear=True)
# Out:
# Number of cosmologies with error > 0.005: 4 out of 300

# %%
figure.suptitle("ResNet errors - 400 train, BACCO smearing")
figure.savefig("resnet_smeared_errors.pdf", bbox_inches="tight")

# %%
resnet_no_smear = keras.models.load_model("models/resnet_nosmear")
figure = evaluate_model(resnet_no_smear, test_samples, test_boosts, 0, smear=False)
# Out:
# Number of cosmologies with error > 0.005: 23 out of 300

# %%
figure.suptitle("ResNet errors - 400 train, no smearing")
figure.savefig("resnet_nosmear_errors.pdf", bbox_inches="tight")
